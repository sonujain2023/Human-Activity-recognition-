# %% [markdown]
# <a href="https://colab.research.google.com/github/sonujain2023/Human-Activity-recognition-/blob/main/Sign_language_Detection_using_Yolo11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Thu May  1 16:46:41 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %% [markdown]
# **Step 01 # Install the Ultralytics Package**

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 13.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 72.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 75.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 49.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 100.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %% [markdown]
# **Step 02 # Import All the Requried Libraries**

# %%
from ultralytics import YOLO
from IPython.display import Image
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %% [markdown]
# **Step # 03 Download Dataset**

# %%
# !unzip yolo11.v1i.yolov11.zip

# %% [markdown]
# **Step # 04 Train YOLO11 Model on a Custom Dataset**

# %%
# !yolo task=detect mode=train data="/content/data.yaml" model="yolo11n.pt" epochs=50 imgsz=640
# Out:
# Ultralytics 8.3.122 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# **Step # 05 Examine Training Results**

# %%
Image("/content/runs/detect/train4/confusion_matrix.png", width=600)

# %%
Image("/content/runs/detect/train4/labels.jpg", width=600)

# %%
Image("/content/runs/detect/train4/results.png", width=600)

# %%
Image("/content/runs/detect/train4/train_batch0.jpg", width=600)

# %%
Image("/content/runs/detect/train4/val_batch0_pred.jpg", width=600)

# %% [markdown]
# **Step # 08 Inference with Custom Model on Images**

# %%
# !yolo task=detect mode=predict model="/content/runs/detect/train4/weights/best.pt" conf=0.25 source="/content/test/images" save=True
# Out:
# Ultralytics 8.3.122 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,583,127 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/14 /content/test/images/No_20250427_141958-49-_jpg.rf.e4b360ae8c1edd4e0ac19fa8c1fdc259.jpg: 640x640 1 no, 12.0ms
# image 2/14 /content/test/images/Please_20250427_141325-50-_jpg.rf.b812552e0e72472817c984a8ae6156b2.jpg: 640x640 1 please, 8.6ms
# image 3/14 /content/test/images/hello-2025-04-26-at-6_53_34-PM_jpeg.rf.240da68871be3cdafd2bc6ddea26c3d3.jpg: 640x640 1 hello, 8.3ms
# image 4/14 /content/test/images/hello-2025-04-29-at-14_23_08-PM-1-_jpg.rf.1fd5d509ee0dc8edb5272725abf92dae.jpg: 640x640 1 hello, 8.1ms
# image 5/14 /content/test/images/hello_20250427_105859_jpg.rf.b63ede46b783059cd0c160c6fe2fb797.jpg: 640x640 1 hello, 7.8ms
# image 6/14 /content/test/images/no_20250427_111716_jpg.rf.15ac091431c445e97dde0e27b2a642e2.jpg: 640x640 1 no, 7.9ms
# ...

# %%
import glob
import os
from IPython.display import Image as IPyImage, display

latest_folder = max(glob.glob('/content/runs/detect/predict*/'), key=os.path.getmtime)
for img in glob.glob(f'{latest_folder}/*.jpg')[1:4]:
    display(IPyImage(filename=img, width=600))
    print("\n")

# %%
# !yolo task=detect mode=predict model= "/content/runs/detect/train4/weights/best.pt" conf=0.25 source="/content/No_20250427_141958 (49).jpg" save=True
# Out:
# Ultralytics 8.3.122 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,583,127 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/1 /content/No_20250427_141958 (49).jpg: 480x640 1 no, 75.7ms
# Speed: 4.8ms preprocess, 75.7ms inference, 194.6ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
Image("/content/runs/detect/predict2/No_20250427_141958 (49).jpg", width=600)

# %% [markdown]
# **Step # 08 Inference with Custom Model on Videos**

# %%
# !yolo task=detect mode=predict model= "/content/runs/detect/train4/weights/best.pt" conf=0.25 source="4629650-uhd_4096_2160_25fps.mp4" save=True
# Out:
# Ultralytics 8.3.122 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,583,127 parameters, 0 gradients, 6.3 GFLOPs
#
# video 1/1 (frame 1/241) /content/4629650-uhd_4096_2160_25fps.mp4: 352x640 1 hello, 47.1ms
# video 1/1 (frame 2/241) /content/4629650-uhd_4096_2160_25fps.mp4: 352x640 1 hello, 14.5ms
# video 1/1 (frame 3/241) /content/4629650-uhd_4096_2160_25fps.mp4: 352x640 (no detections), 15.1ms
# video 1/1 (frame 4/241) /content/4629650-uhd_4096_2160_25fps.mp4: 352x640 1 hello, 15.3ms
# video 1/1 (frame 5/241) /content/4629650-uhd_4096_2160_25fps.mp4: 352x640 1 hello, 15.9ms
# video 1/1 (frame 6/241) /content/4629650-uhd_4096_2160_25fps.mp4: 352x640 1 hello, 16.3ms
# video 1/1 (frame 7/241) /content/4629650-uhd_4096_2160_25fps.mp4: 352x640 1 hello, 15.2ms
# video 1/1 (frame 8/241) /content/4629650-uhd_4096_2160_25fps.mp4: 352x640 1 hello, 15.0ms
# ...

# %%
from IPython.display import HTML
from base64 import b64encode
import os

# Input video path
save_path = '/content/runs/detect/predict3/4629650-uhd_4096_2160_25fps.avi'

# Compressed video path
compressed_path = "/content/result_compressed.mp4"

os.system(f"ffmpeg -i {save_path} -vcodec libx264 {compressed_path}")

# Show video
mp4 = open(compressed_path,'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
